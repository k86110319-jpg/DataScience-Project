# %%
import matplotlib.pyplot as plt

# %%
print("Matplotlib imported successfully")
# Out:
# Matplotlib imported successfully

# %%
x = [1,2,3,4]
y = [10,20,15,30]

plt.plot(x,y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [5,10,15,20,25]

plt.plot(x,y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [50,40,30,20,10]

plt.plot(x,y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [10,30,15,40,20]

plt.plot(x,y)

plt.show()

# %%
x = [10,20,30,40,50]
y = [5,10,15,20,25]

plt.plot(x,y)

plt.show()

# %%
x = [1,2,3,4,5]
y = [100,50,200,80,150]

plt.plot(x,y)

plt.show()

# %%
students = ["A","B","C","D","E"]
marks = [80,70,90,60,85]

plt.plot(students,marks)

plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")

plt.show()

# %%
months = ["Jan","Feb","Mar","Apr","May"]
sales = [2000,3000,2500,4000,3500]

plt.plot(months,sales)

plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.show()

# %%
days = ["Monday","Tuesday","Wednesday","Thursday","Friday"]
temperature = [30,32,31,29,33]

plt.plot(days,temperature)

plt.title("Weekly Temperature")
plt.xlabel("Days")
plt.ylabel("Temperature")

plt.show()

# %%
temperature = [30,32,31,29,33]

print("Highest:", max(temperature))
print("Lowest:", min(temperature))
# Out:
# Highest: 33
# Lowest: 29

# %%
x = [1,2,3,4]
y = [10,20,15,30]

plt.plot(x,y)

plt.show()

# %%
months = ["Jan","Feb","Mar"]
sales = [1000,2000,1500]

plt.plot(months,sales)

plt.show()

# %%
plt.title("My Graph")
# Out:
# Text(0.5, 1.0, 'My Graph')

# %%
plt.xlabel("X values")
plt.ylabel("Y values")
# Out:
# Text(0, 0.5, 'Y values')

# %%
months = ["Jan","Feb","Mar","Apr"]
sales = [2000,3000,2500,4000]

plt.plot(months,sales)

plt.title("Monthly Sales Report")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.show()

# %%
students = ["A","B","C","D"]
marks = [80,90,70,85]

plt.plot(students,marks)

plt.title("Student Marks Report")
plt.xlabel("Students")
plt.ylabel("Marks")

plt.show()

# %%
x = [1,2,3,4]
y = [10,20,15,30]

plt.plot(x,y,color="red")

plt.show()

# %%
plt.plot(x,y,linestyle="--")

plt.show()

# %%
plt.plot(x,y,marker="o")

plt.show()

# %%
plt.plot(x,y,marker = "*" )
plt.show()

# %%
plt.plot(x,y,linewidth=5)

plt.show()

# %%
plt.plot(x,y,linewidth=5)

plt.show()

# %%
x = [1,2,3,4]
y = [10,20,15,30]

plt.plot(
    x,
    y,
    color="green",
    linestyle="--",
    marker="o",
    linewidth=5
)

plt.show()

# %%
months = ["Jan","Feb","Mar","Apr","May"]
sales = [2000,3000,2500,4000,3500]

plt.plot(
    months,
    sales,
    color="blue",
    linestyle="--",
    marker="*",
    linewidth=3
)

plt.title("Monthly Sales Analysis")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.grid()

plt.show()

# %%
students = ["A","B","C","D"]
marks = [80,90,70,85]

plt.plot(
    students,
    marks,
    marker="o"
)

plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")

plt.grid()

plt.show()

# %%
days = ["Mon","Tue","Wed","Thu","Fri"]
study_hours = [2,3,4,2,5]

plt.plot(days,study_hours,marker="o")

plt.title("Daily Study Hours")
plt.xlabel("Days")
plt.ylabel("Hours")

plt.show()

# %%
x = [1,2,3,4]

plt.plot(x,[10,20,30,40],color="red",marker="o")
plt.plot(x,[20,10,40,30],color="blue",marker="*")
plt.plot(x,[30,25,20,15],color="green",marker="s")
plt.plot(x,[15,35,25,45],color="orange",marker="^")
plt.plot(x,[40,30,20,10],color="purple",marker="x")

plt.show()

# %%
students = ["A","B","C","D"]
marks = [75,85,90,70]

plt.plot(students,marks,marker="o")
plt.title("Student Marks Analysis")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.grid()

plt.show()

# %%
months = ["Jan","Feb","Mar","Apr"]
sales = [1000,2000,1500,3000]

plt.plot(months,sales,marker="*")
plt.title("Monthly Sales Analysis")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.show()

# %%
days = ["Mon","Tue","Wed","Thu","Fri"]
temp = [30,32,31,29,33]

plt.plot(days,temp,marker="o")
plt.title("Weekly Temperature")
plt.xlabel("Days")
plt.ylabel("Temperature")

plt.show()

# %%
years = [2020,2021,2022,2023]
population = [100,120,150,180]

plt.plot(years,population,marker="o")

plt.title("Population Growth")
plt.xlabel("Years")
plt.ylabel("Population")

plt.show()

# %%
days = ["Mon","Tue","Wed","Thu","Fri"]
hours = [2,4,3,5,6]

plt.plot(days,hours,marker="*")

plt.title("Daily Study Hours")
plt.xlabel("Days")
plt.ylabel("Hours")

plt.show()

# %%
months = ["Jan","Feb","Mar","Apr"]
sales_2024 = [100,150,120,180]
sales_2025 = [120,160,140,200]

plt.plot(months,sales_2024,label = "Sales 2024")
plt.plot(months,sales_2025,label = "Sales 2025")

plt.title("Monthly Sales Analysis")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.legend()
plt.show()
